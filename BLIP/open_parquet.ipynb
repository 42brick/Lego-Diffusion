# %%
import pandas as pd
import pyarrow.parquet as pq
from pyarrow import csv
import io
from PIL import Image, ImageDraw

# %%
df = pd.read_parquet('./output/ghibli.parquet',engine='pyarrow')
df.head()
# Out:
#                                                image  \
# 0  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 1  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 2  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 3  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# 4  {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
#
#                                                 text
# 0  a woman with red hair standing in front of a w...
# 1   a couple of people that are standing in the snow
# 2              a girl with long red hair and a braid
# 3    a man standing next to a little girl in a field
# 4                  a painting of a fence in the snow

# %%
i = df.image[7]['bytes']
stream = io.BytesIO(i)
img = Image.open(stream)

# %%
img.size
# Out:
# (512, 512)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x12716C894C0>
